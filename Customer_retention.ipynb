# %% [markdown]
# ###  importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the dataset

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
pd.pandas.set_option('display.max_columns',None)
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# We have 269 records and 71 features in the dataset

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# Here  1 features are integer datatypes and 70 features are object datatype

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
df['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
df['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
df['Visual appealing web-page layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
df['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
df['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
df['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
df['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Flipkart.com                                                    15
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
df['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
df['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
df['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
df['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
df['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
df['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.style.use('ggplot')
gender=pd.value_counts(df['1Gender of respondent'],sort= True)
sns.barplot(gender.index,gender.values,  palette='bright')
plt.title('Distribution of Gender', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Gender', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that most of the online shopping are females

# %%
age = df['2 How old are you? '].value_counts()
plt.style.use('ggplot')

plt.figure(figsize=(10, 7))
sns.barplot(age.index,age.values,  palette='bright')
plt.title('Distribution of Age', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Age', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# The most of the people are from the age group of 21 to 40 years

# %%
plt.figure(figsize=(12, 7))
sns.countplot(x=df["2 How old are you? "],hue=df["1Gender of respondent"])
plt.title("Age vs Gender", fontsize = 16)
plt.show()

# %% [markdown]
# Here we can see that females with age group of 21-40 years shopping more than the males.

# %%
plt.figure(figsize=(12,8))
plt.style.use('ggplot')

city=pd.value_counts(df['3 Which city do you shop online from?'],sort= True)
sns.barplot(city.index,city.values,  palette='bright')
plt.title('Distribution of Cities', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('City Name', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# The people from the DelhiNCR shopping more on online.

# %%
plt.figure(figsize=(12,8))
plt.style.use('ggplot')

shpng=pd.value_counts(df['5 Since How Long You are Shopping Online ?'],sort= True)
sns.barplot(shpng.index,shpng.values,  palette='bright')
plt.title('How long online shopping', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Online shopping', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the most of the people more than 4 years of experience in online shopping.

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['7 How do you access the internet while shopping on-line?'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Access of internet for online shopping', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Internet access', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here from the graph we can see that the most of the people use their mobile internet for online shopping

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['8 Which device do you use to access the online shopping?'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Device Used for shopping', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Device Used', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Most of the people used their smart phones for the Online shopping.

# %%
df = df.rename(columns={"10 What is the operating system (OS) of your device?\t\t\t\t                                          ":"Operating System"})

# %%
df = df.rename(columns={"12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ":"Channels"})

# %%
df = df.rename(columns={"13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ":"Reaching online store"})

# %%
df = df.rename(columns={"14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ":"Time for purchasing"})

# %%
df = df.rename(columns={"15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ":"Payment Options"})

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['Operating System'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Operating system Used', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Operating System', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Windows operating systems are used more for the online shopping

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['Channels'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Channels Used to go to Favourite online store', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Channels', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Most of the time Search Engine is used to go the online store for the shopping

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['Payment Options'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Preferred Payments Options', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Payment Options', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the most of the people pay online via their Credit/debit Cards

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')

x=pd.value_counts(df['18 The content on the website must be easy to read and understand'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Content on website', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website content', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the content on the websites that are easy to read and understand ,here most of the people agree with that

# %%
col=['19 Information on similar product to the one highlighted  is important for product comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.',
       '21 All relevant information on listed products must be stated clearly',
       '22 Ease of navigation in website', 
       '23 Loading and processing speed',
       '24 User friendly Interface of the website',
       '25 Convenient Payment methods',
         '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'
        ]
a = 4  # number of rows
b = 2 # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(25,32))

for i in col:
    plt.subplot(a, b, c)
    plt.title('{}'.format(i),fontsize=14,fontweight='bold')
    plt.xlabel(i)
    sns.countplot(df[i],color='blue')
    c = c + 1

plt.show()

# %% [markdown]
# - From above graphs we can see that the most of the peoples are strongly agree with the following details which is provided by the websites:
#
#     1. Information on similar product to the one highlighted  is important for product comparison
#
#     2. Complete information on listed seller and product being offered is important for purchase decision.
#
#     3. All relevant information on listed products must be stated clearly,
#
#     4.  Ease of navigation in website,
#
#     5. Loading and processing speed,
#
#     6. User friendly Interface of the website,
#
#     7. Convenient Payment methods,
#
#     8. Trust that the online retail store will fulfill its part of the transaction at the stipulated time,

# %%
col=['27 Empathy (readiness to assist with queries) towards the customers',
       '28 Being able to guarantee the privacy of the customer',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
       '30 Online shopping gives monetary benefit and discounts',
       '31 Enjoyment is derived from shopping online',
       '32 Shopping online is convenient and flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision',
       '34 Gaining access to loyalty programs is a benefit of shopping online',
        ]
a = 4  # number of rows
b = 2 # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(25,32))

for i in col:
    plt.subplot(a, b, c)
    plt.title('{}'.format(i),fontsize=14,fontweight='bold')
    plt.xlabel(i)
    sns.countplot(df[i],color='green')
    c = c + 1

plt.show()

# %% [markdown]
# - From the above graphs we can see that the most peoples are strongly agree with the following details whic is provided by the website for the online shoppings :
#
#      1. Empathy (readiness to assist with queries) towards the customers,
#
#      2. Being able to guarantee the privacy of the customer,
#
#      3. Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.),
#
#      4. Online shopping gives monetary benefit and discounts,
#
#      5. Enjoyment is derived from shopping online,
#
#      6. Shopping online is convenient and flexible,
#
#      7. Return and replacement policy of the e-tailer is important for purchase decision,
#
#      8. Gaining access to loyalty programs is a benefit of shopping online,

# %%
col=['35 Displaying quality Information on the website improves satisfaction of customers',
       '36 User derive satisfaction while shopping on a good quality website or application',
       '37 Net Benefit derived from shopping online can lead to users satisfaction',
       '38 User satisfaction cannot exist without trust',
       '39 Offering a wide variety of listed product in several category',
       '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',
        ]
a = 7  # number of rows
b = 2 # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(25,50))

for i in col:
    plt.subplot(a, b, c)
    plt.title('{}'.format(i),fontsize=14,fontweight='bold')
    plt.xlabel(i)
    sns.countplot(df[i],color='yellow')
    c = c + 1

plt.show()

# %% [markdown]
# From the above graphs we can see that the most of the time people strongly agreed with the information on the website useful or not but in :
#
#        1- Shopping on your preferred e-tailer enhances your social status,
#
#        2- You feel gratification shopping on your favorite e-tailer,
#
#        3- Shopping on the website helps you fulfill certain roles.
#
# peoples with indifferent with the data are high in numbers.

# %%
plt.figure(figsize=(12,8))
plt.style.use('ggplot')

x=pd.value_counts(df['Easy to use website or application'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Easy to use website', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the person who use all e-commerce websites are very high in numbers

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Visual appealing web-page layout'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Visual appealing web-page layout', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the most of the people who uses only Amazon and flipkart website sees these website more Visual appealing web-page layout.

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Wild variety of product on offer'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Wild variety of product on offer', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that most of the people who uses only two website i.e. amazon and flipkart found that the Wild variety of product on offer are high.

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Complete, relevant description information of products'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Complete, relevant description information of products', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that most people are those who uses only two websites i.e. Amazon.in and Flipkart.com

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Fast loading website speed of website and application'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Fast loading website speed of website and application', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that most people found that Amazon.in is the Fast loading website

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Reliability of the website or application'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Reliability of the website or application', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the Amazon.in is the most Reliable website

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Quickness to complete purchase'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Quickness to complete purchase', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that most of the people found that Amazon website is very quick in completing purchase.

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Availability of several payment options'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Availability of several payment options', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here most of the people are those who uses only two websites i.e. Amazon and Flipkart

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Privacy of customers’ information'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Privacy of customers’ information', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# From the above graph we can see that the Most people feels that the only Amazon.in is most secure website

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Perceived Trustworthiness'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Perceived Trustworthiness', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# From the above graph it is proved that the mostly people thinks that the only Amazon.in is more Trustworthy

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Longer time to get logged in (promotion, sales period)'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Longer time to get logged in (promotion, sales period)', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that Amazon.in takes Longer time to get logged in (promotion, sales period).

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,8))

x=pd.value_counts(df['Longer delivery period'])
sns.barplot(x.index,x.values,  palette='bright',ax=ax[0])

ax[0].set_title('Longer delivery period', fontsize=20)

y=pd.value_counts(df['Speedy order delivery '],sort= True)
sns.barplot(y.index,y.values,  palette="rocket",ax=ax[1])
ax[1].set_title('Speedy order delivery ', fontsize=20)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# From above we can see that Paytm more time for delivery while Amazon.in provide fastest delivery

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Change in website/Application design'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Change in website/Application design', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the most people found that the Change in website/Application design more in the Amazon.in

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Website is as efficient as before'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Website is as efficient as before', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Here we can see that the most people found that the  Amazon.in is more  efficient as before, while snapdeal is the least efficient

# %%
plt.figure(figsize=(12,8))

x=pd.value_counts(df['Which of the Indian online retailer would you recommend to a friend?'],sort= True)
sns.barplot(x.index,x.values,  palette='bright')
plt.title('Which of the Indian online retailer would you recommend to a friend?', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.ylabel('Count', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.xlabel('Website names', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.xticks(rotation=90)
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# Most of the people will recommend Amazon.in to their friends.

# %% [markdown]
# ###  Observations :

# %% [markdown]
# 1) Here the most of the Online customers are females while males are less.
#
# 2) The Age group of these peoples are maximum in between 21-40 years.
#
# 3) The Maximum people are from the Delhi , Noida , Greater Noida and Bangalore.
#
# 4) Most of the people have the 4+ years of experience in online shopping.
#
# 5) Most people use the Mobile Internet while using the online shopping website.
#
# 6) Most people  use mobiles and laptops for the online shopping.
#
# 7) Credit/Debit cards are mostly preferred by the people for the payments.
#
# 8) Mostly people read and understand the information  which is present on the website and the strongly agree with all the data given in  the website.
#
# 9) Most of the people preferred Amazon.in and flipkart.com for the online shopping
#
# 10) Paytm and Snapdeal are very least use website for the online shopping , while amazona and flipkart are very highly using websites.
#
# 11) Among flipkart and Amazon.in, Amazon is more used by the people as it provides security, quick purchasing, many payements options, fastest delivery, trustworthy and easy to use and understand interface.
